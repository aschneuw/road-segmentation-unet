# %%
# %matplotlib inline
import matplotlib.image as mpimg
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import sys
import os

# add source to the Python path
module_path = os.path.abspath(os.path.join('../src'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from images import mirror_border

# %%
test_image1 = mpimg.imread(r"D:\Arno\Dropbox\EPFL\MA - SC4\Machine Learning\ml-chiefs\data\training\images\satImage_001.png")
test_image2 = mpimg.imread(r"D:\Arno\Dropbox\EPFL\MA - SC4\Machine Learning\ml-chiefs\data\training\images\satImage_002.png")

# %%
plt.imshow(test_image1)

# %%
plt.imshow(test_image2)

# %%
images = np.ndarray((2, 400,400,3))

# %%
images[0] = test_image1

# %%
images[1] = test_image2

# %%
extended = mirror_border(images, 86)

# %%
extended.shape
# Out:
# (2, 572, 572, 3)

# %%
plt.imshow(extended[0])

# %%
plt.imshow(extended[1])

# %%
test_image1 = mpimg.imread(r"D:\Arno\Dropbox\EPFL\MA - SC4\Machine Learning\ml-chiefs\data\training\groundtruth\satImage_001.png")
test_image2 = mpimg.imread(r"D:\Arno\Dropbox\EPFL\MA - SC4\Machine Learning\ml-chiefs\data\training\groundtruth\satImage_002.png")

# %%
plt.imshow(test_image1, cmap='Greys_r')

# %%
plt.imshow(test_image2, cmap='Greys_r')

# %%
images = np.ndarray((2, 400,400))
images[0] = test_image1
images[1] = test_image2
extended = mirror_border(images, 86)
plt.imshow(extended[0], cmap='Greys_r')

# %%
plt.imshow(extended[1], cmap='Greys_r')
