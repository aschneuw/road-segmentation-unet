# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append("../src")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from show import satimage_with_mask_files

# %%
image_path = '../data/training/images/satImage_001.png'
mask_path = '../data/training/groundtruth/satImage_001.png'

# %%
satimage_with_mask_files(image_path, mask_path)
# Out:
# <PIL.Image.Image image mode=RGBA size=400x400 at 0x10DCFC978>
