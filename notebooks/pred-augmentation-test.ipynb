# %%
# %matplotlib inline
import matplotlib.image as mpimg
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import sys
import os

# add source to the Python path
module_path = os.path.abspath(os.path.join('../src'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from images import augment_pred_rot_and_flip, img_float_to_uint8

# %%
test_image1 = mpimg.imread(r"D:\Arno\Dropbox\EPFL\MA - SC4\Machine Learning\ml-chiefs\data\training\images\satImage_001.png")
test_image2 = mpimg.imread(r"D:\Arno\Dropbox\EPFL\MA - SC4\Machine Learning\ml-chiefs\data\training\images\satImage_002.png")

# %%
imgs = np.zeros((2,400,400,3))

# %%
imgs[0] = test_image1
imgs[1] = test_image2

# %%
aug_imgs = augment_pred_rot_and_flip(imgs)
# Out:
# Applying rotations: 90, 180, 270 degrees...
# Done

# %%
aug_imgs.shape
# Out:
# (12, 400, 400, 3)

# %%
for im in aug_imgs[:]:
    plt.imshow(im)
    plt.show()

# %%
invert = augment_pred_rot_and_flip(aug_imgs, invert=True)
# Out:
# Applying rotations: 270 degrees...
# Done
# Applying rotations: 180 degrees...
# Done
# Applying rotations: 90 degrees...
# Done

# %%
plt.imshow(invert[0])
plt.show()

# %%
assert np.array_equal(invert[0],test_image1)
